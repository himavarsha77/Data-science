# %%
# Week 1
# Experiment: Introduction to Data Science Tools & Installation
# Program: Verify Python Installation and Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("NumPy Version:", np.__version__)
print("Pandas Version:", pd.__version__)

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]

plt.plot(x, y)
plt.title("Test Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# NumPy Version: 2.0.2
# Pandas Version: 2.2.2
